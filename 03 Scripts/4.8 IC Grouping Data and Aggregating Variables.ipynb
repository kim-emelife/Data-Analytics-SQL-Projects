# %% [markdown]
# # 4.8 Exercise - Grouping Data and Aggregating Variables

# %% [markdown]
# Table of Contents
#
# 01. Importing
#
# 02. Grouping
#
# 03. Aggregating with agg()
#
# 04. Aggregating with transform()
#
# 05. Task: Step 2-7
#
# 06. Export Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Importing data frame

# %%
path = r'C:\Users\31622\OneDrive\Documents\Career Foundry\Instacart Basket Analysis'

# %%
# Importing dataframe 
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
# Check shape of dataframe 
ords_prods_merge.shape
# Out:
# (32434212, 18)

# %%
# Check dataframe structure
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2398795        1                 2                   3                  7
# 2    473747        1                 3                   3                 12
# 3   2254736        1                 4                   4                  7
# 4    431534        1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# check columns in dataframe
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'number_of_orders', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day'],
#       dtype='object')

# %% [markdown]
# Question 2: Find the mean orders for each department in the merged dataframe

# %%
# Group by "product_name" 
ords_prods_merge.groupby('product_name')

# %%
#Split the data into groups based on “department_id.”
#Apply the agg() function to each group to obtain the mean values for the “number_of_orders” column.
ords_prods_merge.groupby('department_id').agg({'number_of_orders': ['mean']})
# Out:
#               number_of_orders
#                           mean
# department_id
# 1                    15.457687
# 2                    17.277920
# 3                    17.179756
# 4                    17.811403
# 5                    15.213779
# 6                    16.439806
# 7                    17.225773
# 8                    15.340520
# 9                    15.895474
# 10                   20.197148
# 11                   16.170828
# 12                   15.887622
# 13                   16.583304
# 14                   16.757377
# 15                   16.165037
# 16                   17.663250
# 17                   15.694469
# 18                   19.310397
# 19                   17.177343
# 20                   16.473447
# 21                   22.902379

# %%
# Importing department_wrangled dataframe
df_dept = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'))
# Importing dataframe to help better understand the different departments in our analysis.

# %%
df_dept
# Out:
#     Unnamed: 0       department
# 0            1           frozen
# 1            2            other
# 2            3           bakery
# 3            4          produce
# 4            5          alcohol
# 5            6    international
# 6            7        beverages
# 7            8             pets
# 8            9  dry goods pasta
# 9           10             bulk
# 10          11    personal care
# 11          12     meat seafood
# 12          13           pantry
# 13          14        breakfast
# 14          15     canned goods
# 15          16       dairy eggs
# 16          17        household
# 17          18           babies
# 18          19           snacks
# 19          20             deli
# 20          21          missing

# %% [markdown]
# Answer 2: Compared to our subset from our practise exercise, we are able to see each department and the mean for this.
# Now we have our full dataframe, we see that the mean recorded for our subset has changed, with less variablity perhaps a better reflecton of variablity of the mean orders.
# for our dataframe. We see in our entire dataframe that the department with minimum mean orders is alcohol (15.2) and the maximum mean orders is missing categories (22.9).
# This missing category indicates a large number of unspecified values for the column "department_id."

# %% [markdown]
# Question 4: Create a loyalty flag for existing customers using the transform and loc functions.

# %%
# groups based by the “user_id” column, generate maximum orders for each user, create “max_order,” results of aggregation.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_orders'].transform(np.max)

# %%
#Check dataframe
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2398795        1                 2                   3                  7
# 2    473747        1                 3                   3                 12
# 3   2254736        1                 4                   4                  7
# 4    431534        1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# Check the data grouping for accuracy
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  number_of_orders  orders_day_of_week  \
# 0    2539329        1                 1                   2
# 1    2398795        1                 2                   3
# 2     473747        1                 3                   3
# 3    2254736        1                 4                   4
# 4     431534        1                 5                   4
# 5    3367565        1                 6                   2
# 6     550135        1                 7                   1
# 7    3108588        1                 8                   1
# 8    2295261        1                 9                   1
# 9    2550362        1                10                   4
# 10   2968173       15                15                   1
# 11   1870022       15                17                   2
# 12   1911383       15                18                   2
# 13   2715276       15                21                   1
# 14    487368       15                22                   1
# ...

# %% [markdown]
# Question 5: Create flags for loyalty labels

# %%
# Create flags to assign "loyalty" labels to user ID based on max order value
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequencies of loyalty flags for accuracy
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'number_of_orders']].head(20)
# Out:
#     user_id      loyalty_flag  number_of_orders
# 0         1      New customer                 1
# 1         1      New customer                 2
# 2         1      New customer                 3
# 3         1      New customer                 4
# 4         1      New customer                 5
# 5         1      New customer                 6
# 6         1      New customer                 7
# 7         1      New customer                 8
# 8         1      New customer                 9
# 9         1      New customer                10
# 10       15  Regular customer                15
# 11       15  Regular customer                17
# 12       15  Regular customer                18
# 13       15  Regular customer                21
# 14       15  Regular customer                22
# 15       19      New customer                 2
# 16       19      New customer                 5
# 17       19      New customer                 7
# 18       21  Regular customer                10
# ...

# %% [markdown]
# Question 5: Compare spending habits across the three types of customers (loyalty groups)

# %%
# Group by "prices" 
ords_prods_merge.groupby('prices')

# %%
# Group data based on “loyalty_flag.”
# Apply the agg() function to obtain the mean values for the “prices” column
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.388747
# New customer      13.294370
# Regular customer  12.496203

# %% [markdown]
# Answer 5: As shown here, the mean prices of products purchased by loyal customers falls below that of new customers and regular customer.

# %% [markdown]
# Question 6: Create a spending flag for each user based on the average price across all their orders - Categorise as 'Low spender' and 'High spender' based on the crieria given

# %%
# Group data by "user_id" column, generate mean product price for each user, create "mean_price" for aggregation results
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.max)

# %%
# Create flags to assign "Spending" labels based on mean prices value 
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'Spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'Spending_flag'] = 'High spender'

# %%
# Check frequencies of spending flags for accuracy
ords_prods_merge['Spending_flag'].value_counts(dropna = False)
# Out:
# High spender    32402635
# Low spender        31577
# Name: Spending_flag, dtype: int64

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  number_of_orders  orders_day_of_week  \
# 0    2539329        1                 1                   2
# 1    2398795        1                 2                   3
# 2     473747        1                 3                   3
# 3    2254736        1                 4                   4
# 4     431534        1                 5                   4
# 5    3367565        1                 6                   2
# 6     550135        1                 7                   1
# 7    3108588        1                 8                   1
# 8    2295261        1                 9                   1
# 9    2550362        1                10                   4
# 10   2968173       15                15                   1
# 11   1870022       15                17                   2
# 12   1911383       15                18                   2
# 13   2715276       15                21                   1
# 14    487368       15                22                   1
# ...

# %%
# Display the dataframe after dropping duplicated column
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'number_of_orders', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'mean_price', 'Spending_flag'],
#       dtype='object')

# %% [markdown]
# Questions 7: Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column.
#
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Group data by "user_id" column, generate median days for each user, create "median_days" for aggregation results
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.max)

# %%
# Check grouping
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  number_of_orders  orders_day_of_week  \
# 0    2539329        1                 1                   2
# 1    2398795        1                 2                   3
# 2     473747        1                 3                   3
# 3    2254736        1                 4                   4
# 4     431534        1                 5                   4
# 5    3367565        1                 6                   2
# 6     550135        1                 7                   1
# 7    3108588        1                 8                   1
# 8    2295261        1                 9                   1
# 9    2550362        1                10                   4
# 10   2968173       15                15                   1
# 11   1870022       15                17                   2
# 12   1911383       15                18                   2
# 13   2715276       15                21                   1
# 14    487368       15                22                   1
# ...

# %%
# Create flags to assign "freqency" labels to user ID based on median days since prior order
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days'] > 10) & (ords_prods_merge['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequencies of spending flags for accuracy
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Non-frequent customer    24509620
# Regular customer          6539471
# Frequent customer         1385121
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  number_of_orders  orders_day_of_week  \
# 0    2539329        1                 1                   2
# 1    2398795        1                 2                   3
# 2     473747        1                 3                   3
# 3    2254736        1                 4                   4
# 4     431534        1                 5                   4
# 5    3367565        1                 6                   2
# 6     550135        1                 7                   1
# 7    3108588        1                 8                   1
# 8    2295261        1                 9                   1
# 9    2550362        1                10                   4
# 10   2968173       15                15                   1
# 11   1870022       15                17                   2
# 12   1911383       15                18                   2
# 13   2715276       15                21                   1
# 14    487368       15                22                   1
# ...

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated.pkl'))
