# %% [markdown]
# # Exercise 4.4

# %% [markdown]
# Table of Contents
#
# 01. Importing
#
# 02. Data Wrangling Procedures¶
#
# 03. Data Dictionary
#
# 04. Subsetting
#
# 05. Task: Steps 2-10
#
# 06. Export Data

# %%
# import liraries
import pandas as pd
import numpy as np
import os

# %%
# Importing data frame - Instacart basket Analysis
path = r'C:\Users\31622\OneDrive\Documents\Career Foundry\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\31622\\OneDrive\\Documents\\Career Foundry\\Instacart Basket Analysis'

# %%
# Importing data set - orders.csv
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
# Importing data set - products.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Dropping eval_set column from orders.csv
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# Replacing df.ords with new version without eval_set
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# Ivestigating missing values in column "days_since_prioir_order"
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
# Renaming column "order_dow" in data set order.csv
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Changing data type of order_id to "str"
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
# Importing data set - departments.csv
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing data frame department.csv
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Creating a new transposed dataframe for department.csv
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Indexing new transposed dataframe department.csv
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of the df_dept_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Set the header row as df header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Set df_dept new dataframe into a data dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# Searching for a subset in df_prods
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
# check data 
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # Exercise 4.4

# %%
# Question 2

# %%
# Finding numeric values in df_ords
df_ords.describe()
# Out:
#             user_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.029782e+05  1.715486e+01        2.776219e+00       1.345202e+01
# std    5.953372e+04  1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.139400e+04  5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.026890e+05  1.100000e+01        3.000000e+00       1.300000e+01
# 75%    1.543850e+05  2.300000e+01        5.000000e+00       1.600000e+01
# max    2.062090e+05  1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
# Changing data type of user_id to str
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtype #dtype '0' now changed to string
# Out:
# dtype('O')

# %%
# Question 3

# %%
# Looking at order.csv dataframe heading
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# rename df_ords column: order_number
df_ords.rename(columns = {'order_number' : 'number_of_orders'}, inplace = True)

# %%
# Checking renamed column - number_of_orders
df_ords.head()
# Out:
#   order_id user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1                 1                   2                  8
# 1  2398795       1                 2                   3                  7
# 2   473747       1                 3                   3                 12
# 3  2254736       1                 4                   4                  7
# 4   431534       1                 5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Question 4: what is the busiest hour for placing orders

# %%
# counting values in df_ords
df_ords['order_hour_of_day'].value_counts(dropna = False) # The busiest hour of the day ia 10.
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
# Question 5: Determine the meaning behind a value of 4 in the "department_id" column within the df_prods

# %%
# Checking first 5 to display fist 5 rows of dataframe df_prods to find headers
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# To find the department_id in df_prods = 4, 
df_prods['department_id']==4
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
# Used df_value to represent reference the new dataframe for searching in department_id
df_value =  df_prods[df_prods['department_id']==4]

# %%
df_value.head()
# Out:
#     product_id                    product_name  aisle_id  department_id  \
# 30          31              White Pearl Onions       123              4
# 42          43             Organic Clementines       123              4
# 44          45               European Cucumber        83              4
# 65          66       European Style Spring Mix       123              4
# 88          89  Yogurt Fruit Dip Sliced Apples       123              4
#
#     prices
# 30     7.5
# 42    11.5
# 44    14.3
# 65    11.7
# 88    12.6

# %%
# Question 6 - Create a subset for breakfast item sales

# %%
# Set df_dept new dataframe into a data dictionary
data_dict = df_dep_t_new.to_dict('index') # Reference df_t_new.to dict from cell 28

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Indexing "department_id" value of 14 within the df_prods dataframe 
df_prods['department_id']==14
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
# Creating df_breakfast to reference our indexed column
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
df_breakfast.describe() # shows frequency of the df_breakfast dataframe. There are 1116 distinct items under the breakfast portfolio
with a maximum price of 14.9 and an average price of 7.8
# Out:
#          product_id     aisle_id  department_id       prices
# count   1116.000000  1116.000000         1116.0  1116.000000
# mean   25464.490143   101.517921           14.0     7.848208
# std    14271.353221    33.890362            0.0     3.971678
# min       28.000000    48.000000           14.0     1.000000
# 25%    12754.250000    57.000000           14.0     4.400000
# 50%    26268.000000   121.000000           14.0     7.700000
# 75%    38035.250000   130.000000           14.0    11.300000
# max    49663.000000   130.000000           14.0    14.900000

# %%
# Question 7 Find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood

# %%
# create an df_prods_dept to represent the grouped departments: alcohol, deli, beverages, meat/seafood
df_prods_dept = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_prods_dept # All observations for the departments: alcohol, deli, beverages, meat/seafood
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# Question 8: How many rows does the last dataframe you created have?

# %%
# There are 7650 rows for departments: alcohol, deli, beverages, meat/seafood

# %%
# Question 9: Extract all the information you can about this user_id = 1

# %%
df_ords
# Out:
#         order_id user_id  number_of_orders  orders_day_of_week  \
# 0        2539329       1                 1                   2
# 1        2398795       1                 2                   3
# 2         473747       1                 3                   3
# 3        2254736       1                 4                   4
# 4         431534       1                 5                   4
# ...          ...     ...               ...                 ...
# 3421078  2266710  206209                10                   5
# 3421079  1854736  206209                11                   4
# 3421080   626363  206209                12                   1
# 3421081  2977660  206209                13                   1
# 3421082   272231  206209                14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ords['user_id']==1
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3421078    False
# 3421079    False
# 3421080    False
# 3421081    False
# 3421082    False
# Name: user_id, Length: 3421083, dtype: bool

# %%
df_userid_1 = df_ords.loc[df_ords['user_id']=='1']
# Out:
#   Cell In[5], line 1
#     df_userid_1 = df_ords.loc[df_ords['user_id']=='1'
#                                                      ^
# SyntaxError: incomplete input

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# number_of_orders            int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# checking user_id for descriptive statistics
df_ords.describe() # data type of user_id changed in question 2 to "str", so descriptive statitics not visible with this function.
# Out:
#        number_of_orders  orders_day_of_week  order_hour_of_day  \
# count      3.421083e+06        3.421083e+06       3.421083e+06
# mean       1.715486e+01        2.776219e+00       1.345202e+01
# std        1.773316e+01        2.046829e+00       4.226088e+00
# min        1.000000e+00        0.000000e+00       0.000000e+00
# 25%        5.000000e+00        1.000000e+00       1.000000e+01
# 50%        1.100000e+01        3.000000e+00       1.300000e+01
# 75%        2.300000e+01        5.000000e+00       1.600000e+01
# max        1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_ords['user_id'].value_counts(dropna = False)
# Out:
# 152340    100
# 185641    100
# 185524    100
# 81678     100
# 70922     100
#          ...
# 13046       4
# 70208       4
# 111440      4
# 31762       4
# 47980       4
# Name: user_id, Length: 206209, dtype: int64

# %%
# Using iloc to check for user_id column. for 2nd column, user_id, 1 is used (for 2nd column..see cell 99)
df_ords.iloc[:,1]
# Out:
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
#             ...
# 3421078    206209
# 3421079    206209
# 3421080    206209
# 3421081    206209
# 3421082    206209
# Name: user_id, Length: 3421083, dtype: object

# %%
# Question 10 Provide some details about this user_id = 1 behavior. What basic stats can you provide based on the information you have?

# %%
# Checking first 30 lines for information on user_id
df_ords.head (30) # based on the below information - user_id = 1, has increases in order each purchase, 
# they typically order early each week and during the day. They order at a minimum, fortnightly basis.
# Out:
#    order_id user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1                 1                   2                  8
# 1   2398795       1                 2                   3                  7
# 2    473747       1                 3                   3                 12
# 3   2254736       1                 4                   4                  7
# 4    431534       1                 5                   4                 15
# 5   3367565       1                 6                   2                  7
# 6    550135       1                 7                   1                  9
# 7   3108588       1                 8                   1                 14
# 8   2295261       1                 9                   1                 16
# 9   2550362       1                10                   4                  8
# 10  1187899       1                11                   4                  8
# ...

# %%
# Exporting df_ords dataframe as orders_wrangled
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
# Exporting df_departments dataframe as deparments_wrangled
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
